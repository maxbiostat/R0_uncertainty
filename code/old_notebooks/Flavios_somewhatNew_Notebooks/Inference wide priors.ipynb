# %% [markdown]
# # Effect of wider priors
# In this notebook we will explore the effects of adopting less precise priors on the estimation of the key parameters of the SIR model given from simulated noisy data. We will use the same models defined in the `Inference_PyMC3` notebook.

# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy.integrate import odeint
import pymc3 as pm
from pymc3.ode import DifferentialEquation
import arviz as az
import theano

# %%
# %config InlineBackend.figure_format = 'retina'
az.style.use("arviz-darkgrid")

# %% [markdown]
# ## Full SIR

# %%
data = np.load('logNSIRdata.npy')
data.shape
# Out:
# (80, 2)

# %%
def SIR(y, t, p):
    ds = -p[0] * y[0] * y[1]
    di = p[0] * y[0] * y[1] - p[1] * y[1]
    return [ds, di]

# %%
sir_model = DifferentialEquation(
    func=SIR,
    times=np.arange(0, 20, 0.25),
    n_states=2,
    n_theta=2,
    t0=0,
)
# Out:
# /usr/local/lib/python3.8/dist-packages/theano/gpuarray/dnn.py:192: UserWarning: Your cuDNN version is more recent than Theano. If you encounter problems, try updating Theano or downgrading cuDNN to a version >= v5 and <= v7.
#   warnings.warn(

# %% [markdown]
# ### Forcing ${\cal R}_0 \geq 1$
# For the following experiment we will double the Standard deviations of the priors compared to our previous experiment.

# %%
with pm.Model() as model:
    sigma = pm.HalfCauchy('sigma', 1, shape=2)

    # Distribuições a priori
    # R0 é limitada inferiormente em 1 para sempre termos uma epidemia.
    R0 = pm.Bound(pm.Normal, lower=1.0)('R0', 2, 6)
    gam = pm.Lognormal('gamma', pm.math.log(2), 4)
    beta = pm.Deterministic('beta', gam * R0)

    sir_curves = sir_model(y0=[0.99, 0.01], theta=[beta, gam])

    Y = pm.Lognormal('Y', mu=pm.math.log(sir_curves), sigma=sigma, observed=data)
#     db = pm.backends.HDF5('traces.h5') # Salva as amostras e assim evita de manter tudo na memória

# %%
with model:
    trace = pm.sample(1000, tune=200, chains=2)
#     prior = pm.sample_prior_predictive()
#     posterior_predictive = pm.sample_posterior_predictive(trace)
# Out:
# /usr/local/lib/python3.8/dist-packages/pymc3/sampling.py:465: FutureWarning: In an upcoming release, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   if v.release[0] > 3 or v.release[1] >= 10:  # type: ignore
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [gamma, R0, sigma]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2400' class='' max='2400' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2400/2400 46:11<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# /usr/local/lib/python3.8/dist-packages/pymc3/math.py:246: RuntimeWarning: divide by zero encountered in log1p
#   return np.where(x < 0.6931471805599453, np.log(-np.expm1(-x)), np.log1p(-np.exp(-x)))
# /usr/local/lib/python3.8/dist-packages/pymc3/math.py:246: RuntimeWarning: divide by zero encountered in log1p
#   return np.where(x < 0.6931471805599453, np.log(-np.expm1(-x)), np.log1p(-np.exp(-x)))
# Sampling 2 chains for 200 tune and 1_000 draw iterations (400 + 2_000 draws total) took 2772 seconds.
# The acceptance probability does not match the target. It is 0.9127130635769783, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9096898251541667, but should be close to 0.8. Try to increase the number of tuning steps.
# The number of effective samples is smaller than 25% for some parameters.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-d38f0bc0c2d5> in <module>
#       1 with model:
#       2     trace = pm.sample(1000, tune=200, chains=2)
# ----> 3     prior = pm.sample_prior_predictive()
#       4     posterior_predictive = pm.sample_posterior_predictive(trace)
#
# /usr/local/lib/python3.8/dist-packages/pymc3/sampling.py in sample_prior_predictive(samples, model, var_names, random_seed)
#    1940     if random_seed is not None:
#    1941         np.random.seed(random_seed)
# -> 1942     names = get_default_varnames(vars_, include_transformed=False)
#    1943     # draw_values fails with auto-transformed variables. transform them later!
#    1944     values = draw_values([model[name] for name in names], size=samples)
#
# /usr/local/lib/python3.8/dist-packages/pymc3/distributions/distribution.py in draw_values(params, point, size)
#     789                     # This may fail for autotransformed RVs, which don't
#     790                     # have the random method
# --> 791                     value = _draw_value(next_, point=point, givens=temp_givens, size=size)
#     792                     givens[next_.name] = (next_, value)
#     793                     drawn[(next_, size)] = value
#
# /usr/local/lib/python3.8/dist-packages/pymc3/distributions/distribution.py in _draw_value(param, point, givens, size)
#     969                 dist_tmp.shape = distshape
#     970                 try:
# --> 971                     return dist_tmp.random(point=point, size=size)
#     972                 except (ValueError, TypeError):
#     973                     # reset shape to account for shape changes
#
# /usr/local/lib/python3.8/dist-packages/pymc3/distributions/continuous.py in random(self, point, size)
#    1882         """
#    1883         mu, tau = draw_values([self.mu, self.tau], point=point, size=size)
# -> 1884         return generate_samples(self._random, mu, tau, dist_shape=self.shape, size=size)
#    1885
#    1886     def logp(self, value):
#
# /usr/local/lib/python3.8/dist-packages/pymc3/distributions/distribution.py in draw_values(params, point, size)
#     832                                 if node.name not in givens and (node, size) in drawn:
#     833                                     givens[node.name] = (node, drawn[(node, size)])
# --> 834                         value = _draw_value(param, point=point, givens=givens.values(), size=size)
#     835                         evaluated[param_idx] = drawn[(param, size)] = value
#     836                         givens[param.name] = (param, value)
#
# /usr/local/lib/python3.8/dist-packages/pymc3/distributions/distribution.py in _draw_value(param, point, givens, size)
#    1004                 input_vals = []
#    1005             func = _compile_theano_function(param, input_vars)
# -> 1006             output = func(*input_vals)
#    1007             return output
#    1008     raise ValueError("Unexpected type in draw_value: %s" % type(param))
#
# ~/.local/lib/python3.8/site-packages/numpy/lib/function_base.py in __call__(self, *args, **kwargs)
#    2111             vargs.extend([kwargs[_n] for _n in names])
#    2112
# -> 2113         return self._vectorize_call(func=func, args=vargs)
#    2114
#    2115     def _get_ufunc_and_otypes(self, func, args):
#
# ~/.local/lib/python3.8/site-packages/numpy/lib/function_base.py in _vectorize_call(self, func, args)
#    2185         """Vectorized call to `func` over positional `args`."""
#    2186         if self.signature is not None:
# -> 2187             res = self._vectorize_call_with_signature(func, args)
#    2188         elif not args:
#    2189             res = func()
#
# ~/.local/lib/python3.8/site-packages/numpy/lib/function_base.py in _vectorize_call_with_signature(self, func, args)
#    2226
#    2227         for index in np.ndindex(*broadcast_shape):
# -> 2228             results = func(*(arg[index] for arg in args))
#    2229
#    2230             n_results = len(results) if isinstance(results, tuple) else 1
#
# /usr/local/lib/python3.8/dist-packages/theano/compile/function/types.py in __call__(self, *args, **kwargs)
#     972         try:
#     973             outputs = (
# --> 974                 self.fn()
#     975                 if output_subset is None
#     976                 else self.fn(output_subset=output_subset)
#
# /usr/local/lib/python3.8/dist-packages/theano/graph/op.py in rval(p, i, o, n)
#     474             # default arguments are stored in the closure of `rval`
#     475             def rval(p=p, i=node_input_storage, o=node_output_storage, n=node):
# --> 476                 r = p(n, [x[0] for x in i], o)
#     477                 for o in node.outputs:
#     478                     compute_map[o][0] = True
#
# /usr/local/lib/python3.8/dist-packages/pymc3/ode/ode.py in perform(self, node, inputs_storage, output_storage)
#     213         y0, theta = inputs_storage[0], inputs_storage[1]
#     214         # simulate states and sensitivities in one forward pass
# --> 215         output_storage[0][0], output_storage[1][0] = self._simulate(y0, theta)
#     216
#     217     def infer_shape(self, fgraph, node, input_shapes):
#
# /usr/local/lib/python3.8/dist-packages/pymc3/ode/ode.py in _simulate(self, y0, theta)
#     124
#     125         # perform the integration
# --> 126         sol = scipy.integrate.odeint(
#     127             func=self._system, y0=s0, t=self._augmented_times, args=(np.concatenate([y0, theta]),)
#     128         ).astype(floatX)
#
# /usr/local/lib/python3.8/dist-packages/scipy/integrate/odepack.py in odeint(func, y0, t, args, Dfun, col_deriv, full_output, ml, mu, rtol, atol, tcrit, h0, hmax, hmin, ixpr, mxstep, mxhnil, mxordn, mxords, printmessg, tfirst)
#     239     t = copy(t)
#     240     y0 = copy(y0)
# --> 241     output = _odepack.odeint(func, y0, t, args, Dfun, col_deriv, ml, mu,
#     242                              full_output, rtol, atol, tcrit, h0, hmax, hmin,
#     243                              ixpr, mxstep, mxhnil, mxordn, mxords,
#
# /usr/local/lib/python3.8/dist-packages/pymc3/ode/ode.py in _system(self, Y, t, p)
#     115             parameter vector (y0, theta)
#     116         """
# --> 117         dydt, ddt_dydp = self._augmented_func(Y[: self.n_states], t, p, Y[self.n_states :])
#     118         derivatives = np.concatenate([dydt, ddt_dydp])
#     119         return derivatives
#
# /usr/local/lib/python3.8/dist-packages/theano/compile/function/types.py in __call__(self, *args, **kwargs)
#     972         try:
#     973             outputs = (
# --> 974                 self.fn()
#     975                 if output_subset is None
#     976                 else self.fn(output_subset=output_subset)
#
# /usr/local/lib/python3.8/dist-packages/theano/scan/op.py in rval(p, i, o, n, allow_gc)
#    1086             r = p(n, [x[0] for x in i], o)
#    1087             for o in node.outputs:
# -> 1088                 compute_map[o][0] = True
#    1089             if allow_gc:
#    1090                 self.fn.free()
#
# KeyboardInterrupt:

# %%
pdata = az.from_pymc3(
    trace=trace,
    #prior=prior,
    #posterior_predictive=posterior_predictive
)
# Out:
# /usr/local/lib/python3.8/dist-packages/arviz/data/io_pymc3.py:96: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   warnings.warn(

# %%
az.plot_posterior(pdata,var_names=['R0','gamma', 'beta']);

# %%
with model:
    vi = pm.fit(method='advi')
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.02% [2/10000 00:00<07:40 Average Loss = 27,208]
#     </div>
# ---------------------------------------------------------------------------
# FloatingPointError                        Traceback (most recent call last)
# <ipython-input-29-b4ad87a8c149> in <module>
#       1 with model:
# ----> 2     vi = pm.fit(method='advi')
#
# /usr/local/lib/python3.8/dist-packages/pymc3/variational/inference.py in fit(n, local_rv, method, model, random_seed, start, inf_kwargs, **kwargs)
#     830     else:
#     831         raise TypeError(f"method should be one of {set(_select.keys())} or Inference instance")
# --> 832     return inference.fit(n, **kwargs)
#
# /usr/local/lib/python3.8/dist-packages/pymc3/variational/inference.py in fit(self, n, score, callbacks, progressbar, **kwargs)
#     148             progress = range(n)
#     149         if score:
# --> 150             state = self._iterate_with_loss(0, n, step_func, progress, callbacks)
#     151         else:
#     152             state = self._iterate_without_loss(0, n, step_func, progress, callbacks)
#
# /usr/local/lib/python3.8/dist-packages/pymc3/variational/inference.py in _iterate_with_loss(self, s, n, step_func, progress, callbacks)
#     236                     except IndexError:
#     237                         pass
# --> 238                     raise FloatingPointError("\n".join(errmsg))
#     239                 scores[i] = e
#     240                 if i % 10 == 0:
#
# FloatingPointError: NaN occurred in optimization.
# The current approximation of RV `sigma_log__`.ravel()[1] is NaN.
# The current approximation of RV `R0_lowerbound__`.ravel()[0] is NaN.
# The current approximation of RV `gamma_log__`.ravel()[0] is NaN.
# Try tracking this parameter: http://docs.pymc.io/notebooks/variational_api_quickstart.html#Tracking-parameters

# %%
pm.plot_posterior(vi.sample(1000), color="LightSeaGreen");

# %% [markdown]
# ### Letting $\beta$ and $\gamma$ vary independently

# %%
with pm.Model() as model2:
    sigma = pm.HalfCauchy('sigma', 1, shape=2)

    gam = pm.Lognormal('gamma', pm.math.log(2), 4)
    beta = pm.Lognormal('beta', pm.math.log(4), 4)

    sir_curves = sir_model(y0=[0.99, 0.01], theta=[beta, gam])

    Y = pm.Lognormal('Y', mu=pm.math.log(sir_curves), sigma=sigma, observed=data)
#     db = pm.backends.HDF5('traces.h5') # Salva as amostras e assim evita de manter tudo na memória

# %%
with model2:
    trace2 = pm.sample(1000, tune=500, chains=2)
# Out:
# /usr/local/lib/python3.8/dist-packages/pymc3/sampling.py:465: FutureWarning: In an upcoming release, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   if v.release[0] > 3 or v.release[1] >= 10:  # type: ignore
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 4 jobs)
# NUTS: [beta, gamma, sigma]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3000' class='' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3000/3000 24:27<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# /usr/local/lib/python3.8/dist-packages/pymc3/math.py:246: RuntimeWarning: divide by zero encountered in log1p
#   return np.where(x < 0.6931471805599453, np.log(-np.expm1(-x)), np.log1p(-np.exp(-x)))
# /usr/local/lib/python3.8/dist-packages/pymc3/math.py:246: RuntimeWarning: divide by zero encountered in log1p
#   return np.where(x < 0.6931471805599453, np.log(-np.expm1(-x)), np.log1p(-np.exp(-x)))
# Sampling 2 chains for 500 tune and 1_000 draw iterations (1_000 + 2_000 draws total) took 1467 seconds.
# The acceptance probability does not match the target. It is 0.8947143205578115, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9018197547531033, but should be close to 0.8. Try to increase the number of tuning steps.

# %%
pdata2 = az.from_pymc3(
    trace=trace2,
    #prior=prior,
    #posterior_predictive=posterior_predictive
)
# Out:
# /usr/local/lib/python3.8/dist-packages/arviz/data/io_pymc3.py:96: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   warnings.warn(

# %%
az.plot_posterior(pdata2,var_names=['gamma', 'beta']);

# %%
az.plot_trace(pdata2,var_names=['gamma', 'beta']);
